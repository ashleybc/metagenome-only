# %% [markdown]
# This code will show how to trim and assemble of paired-end metagenome .fastq.gz files in BASH using bbtools and SPAdes.
#
# Sample data from ENA:
#
# Arctic Ocean metagenomes sampled aboard CGC Healy during the 2015 GEOTRACES Arctic research cruise Secondary Study Accession:ERP015773 Study Title:Arctic Ocean metagenomes from HLY1502 Center Name:UNIVERSITY OF ALASKA FAIRBANKS Study Name:Arctic Ocean metagenomes ENA-FIRST-PUBLIC:2016-05-27 ENA-LAST-UPDATE:2016-05-25
#
# Can be found at: https://www.ebi.ac.uk/ena/browser/view/PRJEB14154?show=reads
#
# I have used the first 5 pairs of Generated FASTQ files
#
# move into content folder:

# %%
cd example_content

# %% [markdown]
# examine content...notice all of the .fastq.gz files are in separate subfolders

# %%
ls
# Out:
# ERR1424899	ERR1424900	ERR1424901	ERR1424902	ERR1424903

# %% [markdown]
# move up one directory and create a new subdirectory to move all of the .fastq.gz files into one place. Then check that the directory was made with ls.

# %%
cd ..

# %% [markdown]
# First, we need to make a copy of the original data before moving it

# %%
cp -R example_content example_content_copy

# %%
mkdir all_data

# %%
ls
# Out:
# Mapping_simple.ipynb			references
# all_data				spadsandstatswrapcommands.txt
# bowtie2andsamtoolscommands.txt		trimming_assembly_basic.ipynb
# example_content				trimming_classification_basic.ipynb
# example_content_2			trimming_classification_moreqc.ipynb
# example_content_copy

# %% [markdown]
# move back to example_content directory

# %%
cd example_content

# %% [markdown]
# locate all files ending with .gz in all subfolders within the directory. The `*` character means that any other characters can preceed .gz. The `mindepth` command specifies to perform commands that follow at the subdirectory level (1=root). The empty `{}` allows all files meeting the criteria to be moved.  The `print` command allows user to monitor files

# %%
find . -mindepth 2 -type f -name '*.gz' -print -exec mv {} ../all_data \;
# Out:
# ./ERR1424899/ERR1424899_1.fastq.gz
# ./ERR1424899/ERR1424899_2.fastq.gz
# ./ERR1424900/ERR1424900_1.fastq.gz
# ./ERR1424900/ERR1424900_2.fastq.gz
# ./ERR1424901/ERR1424901_1.fastq.gz
# ./ERR1424901/ERR1424901_2.fastq.gz
# ./ERR1424902/ERR1424902_1.fastq.gz
# ./ERR1424902/ERR1424902_2.fastq.gz
# ./ERR1424903/ERR1424903_1.fastq.gz
# ./ERR1424903/ERR1424903_2.fastq.gz

# %% [markdown]
# move into the `all_data` subdirectory to check that all the `.fastq.gz` files have moved.

# %%
cd ../all_data

# %%
ls
# Out:
# ERR1424899_1.fastq.gz	ERR1424901_1.fastq.gz	ERR1424903_1.fastq.gz
# ERR1424899_2.fastq.gz	ERR1424901_2.fastq.gz	ERR1424903_2.fastq.gz
# ERR1424900_1.fastq.gz	ERR1424902_1.fastq.gz
# ERR1424900_2.fastq.gz	ERR1424902_2.fastq.gz

# %% [markdown]
# Now, we delete the original example_content directory, which is empty.

# %%
rm -r ../example_content

# %% [markdown]
# Let's go through trimming and assembly using one pair of read files

# %% [markdown]
# First, I am going to trim reads using a few trimming commands with the tool BBDUK from bbtools prior to assembly using SPAdes
# We call the tool bbduk within bbtools by `bbduk.sh`.
#
# Let's star with basic trimming
#
#
# Provide input file and output directory/name. The reference library used for trimming is adapters, which contains all illumina adapter sequences. `ktrim` directions determine whether the 3' (right) or 5' (left) adapters are trimmed. In this case, we are setting it to trim the 3' adapter. `tbo` indicates trim by overlap

# %%
mkdir ../trimmed_reads

# %%
bbduk.sh in=ERR1424899_1.fastq.gz in2=ERR1424899_2.fastq.gz out=../trimmed_reads/trimmed_ERR1424899.fq.gz ktrim=r k=23 mink=11 hdist=1 tbo minlen=70 ref=adapters ordered ow=t
# Out:
# /usr/local/Cellar/bbtools/38.95/libexec//calcmem.sh: line 75: [: -v: unary operator expected
# Max memory cannot be determined.  Attempting to use 1400 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -ea -Xmx1400m -Xms1400m -cp /usr/local/Cellar/bbtools/38.95/libexec/current/ jgi.BBDuk in=ERR1424899_1.fastq.gz in2=ERR1424899_2.fastq.gz out=../trimmed_reads/trimmed_ERR1424899.fq.gz ktrim=r k=23 mink=11 hdist=1 tbo minlen=70 ref=adapters ow=t
# Executing jgi.BBDuk [in=ERR1424899_1.fastq.gz, in2=ERR1424899_2.fastq.gz, out=../trimmed_reads/trimmed_ERR1424899.fq.gz, ktrim=r, k=23, mink=11, hdist=1, tbo, minlen=70, ref=adapters, ow=t]
# Version 38.95
#
# maskMiddle was disabled because useShortKmers=true
# 0.062 seconds.
# Initial:
# Memory: max=1468m, total=1468m, free=1439m, used=29m
#
# Added 217135 kmers; time: 	0.285 seconds.
# Memory: max=1468m, total=1468m, free=1434m, used=34m
#
# Input is being processed as paired
# Started output streams:	0.316 seconds.
# Processing time:   		81.942 seconds.
#
# Input:                  	5416140 reads 		937014505 bases.
# KTrimmed:               	33061 reads (0.61%) 	4284847 bases (0.46%)
# Trimmed by overlap:     	4010 reads (0.07%) 	306617 bases (0.03%)
# Total Removed:          	547892 reads (10.12%) 	36663036 bases (3.91%)
# Result:                 	4868248 reads (89.88%) 	900351469 bases (96.09%)
#
# Time:                         	82.547 seconds.
# Reads Processed:       5416k 	65.61k reads/sec
# Bases Processed:        937m 	11.35m bases/sec

# %% [markdown]
# Notice that 90% of reads (96% of bases) were retained after ktrimming and trimming by overlap
#
# Next, let's remove any synthetic DNA (spike-ins) and other such artifacts from the trimmed reads using `bbduk.sh` . The argument `cardinality` will approximate the unique number of k-mers. `phix` refers to a virus that is often spiked in during sequencing runs. `ordered` indicates that the input order will be the same as in the prior command.

# %%
mkdir ../artfilt_reads

# %%
bbduk.sh in=../trimmed_reads/trimmed_ERR1424899.fq.gz  out=../artfilt_reads/artfilt_ERR1424899.fq.gz  k=31 ref=artifacts,phix ordered cardinality ow=t;
# Out:
# /usr/local/Cellar/bbtools/38.95/libexec//calcmem.sh: line 75: [: -v: unary operator expected
# Max memory cannot be determined.  Attempting to use 1400 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -ea -Xmx1400m -Xms1400m -cp /usr/local/Cellar/bbtools/38.95/libexec/current/ jgi.BBDuk in=../trimmed_reads/trimmed_ERR1424899.fq.gz out=../artfilt_reads/artfilt_ERR1424899.fq.gz k=31 ref=artifacts,phix ordered cardinality ow=t
# Executing jgi.BBDuk [in=../trimmed_reads/trimmed_ERR1424899.fq.gz, out=../artfilt_reads/artfilt_ERR1424899.fq.gz, k=31, ref=artifacts,phix, ordered, cardinality, ow=t]
# Version 38.95
#
# Set ORDERED to true
# 0.035 seconds.
# Initial:
# Memory: max=1468m, total=1468m, free=1439m, used=29m
#
# Added 92346 kmers; time: 	0.174 seconds.
# Memory: max=1468m, total=1468m, free=1433m, used=35m
#
# Input is being processed as paired
# Started output streams:	0.070 seconds.
# Processing time:   		60.333 seconds.
#
# Input:                  	4868248 reads 		900351469 bases.
# Contaminants:           	0 reads (0.00%) 	0 bases (0.00%)
# Total Removed:          	0 reads (0.00%) 	0 bases (0.00%)
# Result:                 	4868248 reads (100.00%) 	900351469 bases (100.00%)
# Unique 31-mers:         	401357305
#
# Time:                         	60.586 seconds.
# Reads Processed:       4868k 	80.35k reads/sec
# Bases Processed:        900m 	14.86m bases/sec

# %% [markdown]
# There were no contaminants, so 100% of reads and bases from the prior step were retained.

# %% [markdown]
# Finally, let's take the trimmed, contaminant-free reads and do further quality trimming to remove any low-quality or low-entropy reads

# %%
mkdir ../qtrimmed

# %%
bbduk.sh in=../artfilt_reads/artfilt_ERR1424899.fq.gz out=../qtrimmed_reads/qtrimmed_ERR1424899.fq.gz  qtrim=r trimq=10 minlen=70 ordered maxns=0 maq=8 entropy=0.95 ow=t;
# Out:
# /usr/local/Cellar/bbtools/38.95/libexec//calcmem.sh: line 75: [: -v: unary operator expected
# Max memory cannot be determined.  Attempting to use 1400 MB.
# If this fails, please add the -Xmx flag (e.g. -Xmx24g) to your command,
# or run this program qsubbed or from a qlogin session on Genepool, or set ulimit to an appropriate value.
# java -ea -Xmx1400m -Xms1400m -cp /usr/local/Cellar/bbtools/38.95/libexec/current/ jgi.BBDuk in=../artfilt_reads/artfilt_ERR1424899.fq.gz out=../qtrimmed_reads/qtrimmed_ERR1424899.fq.gz qtrim=r trimq=10 minlen=70 ordered maxns=0 maq=8 entropy=0.95 ow=t
# Executing jgi.BBDuk [in=../artfilt_reads/artfilt_ERR1424899.fq.gz, out=../qtrimmed_reads/qtrimmed_ERR1424899.fq.gz, qtrim=r, trimq=10, minlen=70, ordered, maxns=0, maq=8, entropy=0.95, ow=t]
# Version 38.95
#
# Set ORDERED to true
# 0.047 seconds.
# Initial:
# Memory: max=1468m, total=1468m, free=1439m, used=29m
#
# Input is being processed as paired
# Started output streams:	0.102 seconds.
# Processing time:   		49.072 seconds.
#
# Input:                  	4868248 reads 		900351469 bases.
# QTrimmed:               	4266 reads (0.09%) 	13603 bases (0.00%)
# Low quality discards:   	0 reads (0.00%) 	0 bases (0.00%)
# Low entropy discards:   	738834 reads (15.18%) 	141640143 bases (15.73%)
# Total Removed:          	738836 reads (15.18%) 	141653746 bases (15.73%)
# Result:                 	4129412 reads (84.82%) 	758697723 bases (84.27%)
#
# Time:                         	49.178 seconds.
# Reads Processed:       4868k 	98.99k reads/sec
# Bases Processed:        900m 	18.31m bases/sec

# %% [markdown]
# Notice that through qtrimming, no low-quality reads or bases were discarded. However, 15% of reads were discarded due to low entropy (likely, repeats), resulting in 84% of reads and bases being retained from the prior step.

# %% [markdown]
# Now, we are ready to assemble the fully QC'd and trimmed pair of read files using SPAdes. Notice that I have selected `--only-assembler` to skip error correction because we have already QC'd this data. The input data flags `--meta` and `--12` indicate that the input file contains interlaced forward and reverse paired-end metagenome reads

# %%
mkdir ../SPAdes_out

# %%
spades.py -o ../SPAdes_out/ERR1424899_spades --meta --12 ../qtrimmed_reads/qtrimmed_ERR1424899.fq.gz --only-assembler
# Out:
# Command line: /Users/ashley/miniconda3/envs/metagenome/bin/spades.py	-o	/Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades	--meta	--12	/Volumes/Ashley's External Drive/metagenome-demos/qtrimmed_reads/qtrimmed_ERR1424899.fq.gz	--only-assembler
#
# System information:
#   SPAdes version: 3.15.2
#   Python version: 3.7.11
#   OS: Darwin-21.2.0-x86_64-i386-64bit
#
# Output dir: /Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades
# Mode: ONLY assembling (without read error correction)
# Debug mode is turned OFF
#
# Dataset parameters:
#   Metagenomic mode
#   Reads:
#     Library number: 1, library type: paired-end
#       orientation: fr
#       left reads: not specified
#       right reads: not specified
#       interlaced reads: ["/Volumes/Ashley's External Drive/metagenome-demos/qtrimmed_reads/qtrimmed_ERR1424899.fq.gz"]
#       single reads: not specified
#       merged reads: not specified
# Assembly parameters:
#   k: [21, 33, 55]
#   Repeat resolution is enabled
#   Mismatch careful mode is turned OFF
#   MismatchCorrector will be SKIPPED
#   Coverage cutoff is turned OFF
# Other parameters:
#   Dir for temp files: /Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/tmp
#   Threads: 16
#   Memory limit (in Gb): 250
#
#
# ======= SPAdes pipeline started. Log can be found here: /Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/spades.log
#
# /Volumes/Ashley's External Drive/metagenome-demos/qtrimmed_reads/qtrimmed_ERR1424899.fq.gz: max reads length: 300
#
# Reads length: 300
#
#
# ===== Before start started.
#
#
# ===== Preprocess reads started.
#
#
# ===== Preprocess reads finished.
#
#
# ===== Assembling started.
#
#
# ===== K21 started.
#
#
# == Running: /Users/ashley/miniconda3/envs/metagenome/bin/spades-core /Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/K21/configs/config.info /Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/K21/configs/mda_mode.info /Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/K21/configs/meta_mode.info
#
#   0:00:00.000     1M / 6M    INFO    General                 (main.cpp                  :  99)   Loaded config from /Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/K21/configs/config.info
#   0:00:00.000     1M / 6M    INFO    General                 (main.cpp                  :  99)   Loaded config from /Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/K21/configs/mda_mode.info
#   0:00:00.006     1M / 6M    INFO    General                 (main.cpp                  :  99)   Loaded config from /Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/K21/configs/meta_mode.info
#   0:00:00.016     1M / 6M    INFO    General                 (memory_limit.cpp          :  48)   Memory limit set to 250 Gb
#   0:00:00.026     1M / 6M    INFO    General                 (main.cpp                  : 107)   Starting SPAdes, built from refs/heads/master, git revision 54bed604152fd271b68bdf7b78bfd0788ea9e431
#   0:00:00.030     1M / 6M    INFO    General                 (main.cpp                  : 108)   Maximum k-mer length: 128
#   0:00:00.030     1M / 6M    INFO    General                 (main.cpp                  : 109)   Assembling dataset (/Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/dataset.info) with K=21
#   0:00:00.031     1M / 6M    INFO    General                 (main.cpp                  : 110)   Maximum # of threads to use (adjusted due to OMP capabilities): 4
#   0:00:00.031     1M / 6M    INFO    General                 (pipeline.cpp              : 212)   SPAdes started
#   0:00:00.031     1M / 6M    INFO    General                 (pipeline.cpp              : 225)   Starting from stage: read_conversion
#   0:00:00.033     1M / 6M    INFO    General                 (pipeline.cpp              : 231)   Two-step repeat resolution disabled
#   0:00:00.043     1M / 6M    INFO   GraphCore                (graph_core.hpp            : 672)   Graph created, vertex min_id: 3, edge min_id: 3
#   0:00:00.053     1M / 6M    INFO   GraphCore                (graph_core.hpp            : 673)   Vertex size: 48, edge size: 40
#   0:00:00.060     1M / 6M    INFO    General                 (edge_index.hpp            : 115)   Size of edge index entries: 12/8
#   0:00:00.060     1M / 7M    INFO   StageManager             (stage.cpp                 : 185)   STAGE == Binary Read Conversion (id: read_conversion)
#   0:00:00.063     1M / 7M    INFO    General                 (read_converter.cpp        :  72)   Converting reads to binary format for library #0 (takes a while)
#   0:00:00.064     1M / 7M    INFO    General                 (read_converter.cpp        :  73)   Converting paired reads
#   0:00:00.705    34M / 43M   INFO    General                 (binary_converter.cpp      :  96)   16384 reads processed
#   0:00:00.745    34M / 52M   INFO    General                 (binary_converter.cpp      :  96)   32768 reads processed
#   0:00:01.198    34M / 79M   INFO    General                 (binary_converter.cpp      :  96)   65536 reads processed
#   0:00:01.773    34M / 118M  INFO    General                 (binary_converter.cpp      :  96)   131072 reads processed
#   0:00:02.958    34M / 140M  INFO    General                 (binary_converter.cpp      :  96)   262144 reads processed
#   0:00:05.196    34M / 140M  INFO    General                 (binary_converter.cpp      :  96)   524288 reads processed
#   0:00:09.262    34M / 155M  INFO    General                 (binary_converter.cpp      :  96)   1048576 reads processed
#   0:00:18.712    34M / 156M  INFO    General                 (binary_converter.cpp      : 111)   2064706 reads written
#   0:00:18.718    16M / 156M  INFO    General                 (read_converter.cpp        :  81)   Converting single reads
#   0:00:18.719    24M / 156M  INFO    General                 (binary_converter.cpp      : 111)   0 reads written
#   0:00:18.719    16M / 156M  INFO    General                 (read_converter.cpp        :  87)   Converting merged reads
#   0:00:18.719    24M / 156M  INFO    General                 (binary_converter.cpp      : 111)   0 reads written
#   0:00:18.755     1M / 156M  INFO   StageManager             (stage.cpp                 : 185)   STAGE == de Bruijn graph construction (id: construction)
#   0:00:18.858     1M / 156M  INFO    General                 (construction.cpp          : 153)   Max read length 300
#   0:00:18.869     1M / 156M  INFO    General                 (construction.cpp          : 159)   Average read length 183.73
#   0:00:18.879     1M / 156M  INFO    General                 (stage.cpp                 : 117)   PROCEDURE == k+1-mer counting (id: construction:kpomer_counting)
#   0:00:18.891     1M / 157M  INFO    General                 (kmer_index_builder.hpp    : 243)   Splitting kmer instances into 40 files using 4 threads. This might take a while.
#   0:00:18.904     1M / 157M  INFO    General                 (file_limit.hpp            :  32)   Open file limit set to 4096
#   0:00:18.935     1M / 157M  INFO    General                 (kmer_splitter.hpp         :  93)   Memory available for splitting buffers: 20.8333 Gb
#   0:00:18.952     1M / 157M  INFO    General                 (kmer_splitter.hpp         : 101)   Using cell size of 1677721
#   0:00:55.821  2401M / 2401M INFO    General                 (kmer_splitters.hpp        : 125)   Processed 3301123 reads
#   0:01:27.625  2401M / 2401M INFO    General                 (kmer_splitters.hpp        : 125)   Processed 6591484 reads
#   0:01:44.343  2401M / 2401M INFO    General                 (kmer_splitters.hpp        : 125)   Processed 8258824 reads
#   0:01:44.343     1M / 418M  INFO    General                 (kmer_splitters.hpp        : 131)   Used 8258824 reads
#   0:01:44.614     1M / 418M  INFO    General                 (kmer_index_builder.hpp    : 249)   Starting k-mer counting.
#   0:03:25.690     1M / 418M  INFO    General                 (kmer_index_builder.hpp    : 260)   K-mer counting done. There are 339657375 kmers in total.
#   0:03:25.690     1M / 418M  INFO    General                 (stage.cpp                 : 117)   PROCEDURE == Extension index construction (id: construction:extension_index_construction)
#   0:03:25.796     1M / 418M  INFO   K-mer Index Building     (kmer_index_builder.hpp    : 438)   Building kmer index
#   0:03:25.798     1M / 418M  INFO    General                 (kmer_index_builder.hpp    : 243)   Splitting kmer instances into 40 files using 4 threads. This might take a while.
#   0:03:25.798     1M / 418M  INFO    General                 (file_limit.hpp            :  32)   Open file limit set to 4096
#   0:03:25.823     1M / 418M  INFO    General                 (kmer_splitter.hpp         :  93)   Memory available for splitting buffers: 20.8333 Gb
#   0:03:25.834     1M / 418M  INFO    General                 (kmer_splitter.hpp         : 101)   Using cell size of 1677721
#   0:03:28.038  2401M / 2401M INFO    General                 (kmer_splitters.hpp        : 194)   Processed 7548346 kmers
#   0:03:36.842  2401M / 2401M INFO    General                 (kmer_splitters.hpp        : 194)   Processed 39908047 kmers
#   0:03:48.386  2401M / 2401M INFO    General                 (kmer_splitters.hpp        : 194)   Processed 73813988 kmers
#   0:04:04.000  2401M / 2401M INFO    General                 (kmer_splitters.hpp        : 194)   Processed 107774411 kmers
#   0:04:20.473  2401M / 2401M INFO    General                 (kmer_splitters.hpp        : 194)   Processed 141736425 kmers
#   0:04:38.944  2401M / 2401M INFO    General                 (kmer_splitters.hpp        : 194)   Processed 175702602 kmers
#   0:04:56.005  2401M / 2401M INFO    General                 (kmer_splitters.hpp        : 194)   Processed 209667269 kmers
#   0:05:13.628  2401M / 2401M INFO    General                 (kmer_splitters.hpp        : 194)   Processed 243637344 kmers
#   0:05:32.044  2401M / 2401M INFO    General                 (kmer_splitters.hpp        : 194)   Processed 277606660 kmers
#   0:05:49.022  2401M / 2401M INFO    General                 (kmer_splitters.hpp        : 194)   Processed 311565743 kmers
#   0:06:03.509  2401M / 2401M INFO    General                 (kmer_splitters.hpp        : 194)   Processed 339657595 kmers
#   0:06:03.509  2401M / 2401M INFO    General                 (kmer_splitters.hpp        : 199)   Used 339657595 kmers.
#   0:06:03.509     1M / 286M  INFO    General                 (kmer_index_builder.hpp    : 249)   Starting k-mer counting.
#   0:09:09.249     1M / 286M  INFO    General                 (kmer_index_builder.hpp    : 260)   K-mer counting done. There are 339297732 kmers in total.
#   0:09:09.249     1M / 286M  INFO   K-mer Index Building     (kmer_index_builder.hpp    : 395)   Building perfect hash indices
#   0:11:15.312   253M / 253M  INFO   K-mer Index Building     (kmer_index_builder.hpp    : 431)   Index built. Total 339297732 kmers, 245091712 bytes occupied (5.7788 bits per kmer).
#   0:11:15.312   253M / 253M  INFO    General                 (kmer_index_builder.hpp    : 169)   Merging final buckets.
#   0:13:08.355   578M / 578M  INFO   DeBruijnExtensionIndexBu (kmer_extension_index_build: 100)   Building k-mer extensions from k+1-mers
#   0:16:05.037   578M / 578M  INFO   DeBruijnExtensionIndexBu (kmer_extension_index_build: 105)   Building k-mer extensions from k+1-mers finished.
#   0:16:05.039   578M / 578M  INFO    General                 (stage.cpp                 : 117)   PROCEDURE == Early tip clipping (id: construction:early_tip_clipper)
#   0:16:05.041   578M / 578M  INFO    General                 (construction.cpp          : 301)   Early tip clipper length bound set as (RL - K)
#   0:16:05.043   578M / 578M  INFO   Early tip clipping       (early_simplification.hpp  :  47)   Early tip clipping
#   0:18:32.180   658M / 658M  INFO   Early tip clipping       (early_simplification.hpp  :  82)   #tipped junctions: 1134979
#   0:18:33.208   658M / 658M  INFO   Early tip clipping       (early_simplification.hpp  :  93)   Clipped tips: 1142899
#   0:18:33.209   578M / 639M  INFO   Early tip clipping       (early_simplification.hpp  :  49)   45066773 22-mers were removed by early tip clipper
#   0:18:33.210   578M / 639M  INFO    General                 (stage.cpp                 : 117)   PROCEDURE == Condensing graph (id: construction:graph_condensing)
#   0:18:35.791   578M / 639M  INFO   UnbranchingPathExtractor (debruijn_graph_constructor: 354)   Extracting unbranching paths
#   0:21:25.749   842M / 2658M INFO   UnbranchingPathExtractor (debruijn_graph_constructor: 373)   Extracting unbranching paths finished. 5432372 sequences extracted
#   0:22:30.163   842M / 913M  INFO   UnbranchingPathExtractor (debruijn_graph_constructor: 309)   Collecting perfect loops
#   0:24:39.213   875M / 2749M INFO   UnbranchingPathExtractor (debruijn_graph_constructor: 342)   Collecting perfect loops finished. 5190 loops collected
#   0:24:40.456   843M / 849M  INFO    General                 (debruijn_graph_constructor: 487)   Total 10875124 edges to create
#   0:24:40.457  1264M / 1264M INFO    General                 (debruijn_graph_constructor: 489)   Collecting link records
#   0:24:44.737  1433M / 1433M INFO    General                 (debruijn_graph_constructor: 491)   Ordering link records
#   0:24:46.028  1433M / 1433M INFO    General                 (debruijn_graph_constructor: 493)   Sorting done
#   0:24:46.241  1497M / 1497M INFO    General                 (debruijn_graph_constructor: 503)   Total 5077919 vertices to create
#   0:24:46.243  1966M / 1966M INFO    General                 (debruijn_graph_constructor: 506)   Connecting the graph
#   0:24:50.224  1650M / 1672M INFO    General                 (stage.cpp                 : 117)   PROCEDURE == Filling coverage indices (PHM) (id: construction:coverage_filling_phm)
#   0:24:50.225  1650M / 1672M INFO   K-mer Index Building     (kmer_index_builder.hpp    : 395)   Building perfect hash indices
#   0:26:58.830  1903M / 1903M INFO   K-mer Index Building     (kmer_index_builder.hpp    : 431)   Index built. Total 339657375 kmers, 245351488 bytes occupied (5.7788 bits per kmer).
#   0:27:00.405  3199M / 3199M INFO    General                 (coverage_hash_map_builder.:  47)   Collecting k-mer coverage information from reads, this takes a while.
#   0:31:06.286  3199M / 3199M INFO    General                 (construction.cpp          : 430)   Filling coverage and flanking coverage from PHM
#   0:31:48.874  3199M / 3199M INFO    General                 (coverage_filling.hpp      :  82)   Processed 4000000 edges
#   0:32:37.455  3199M / 3199M INFO    General                 (coverage_filling.hpp      :  82)   Processed 8000000 edges
#   0:33:06.037  3199M / 3199M INFO    General                 (coverage_filling.hpp      :  82)   Processed 10872348 edges
#   0:33:06.966  1073M / 1073M INFO   StageManager             (stage.cpp                 : 185)   STAGE == Raw Simplification (id: raw_simplification)
#   0:33:06.968  1073M / 1073M INFO    General                 (simplification.cpp        : 127)   PROCEDURE == Initial cleaning
#   0:33:06.984  1073M / 1073M INFO    General                 (graph_simplification.hpp  : 662)   Flanking coverage based disconnection disabled
#   0:33:06.984  1073M / 1073M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Self conjugate edge remover
#   0:33:07.751  1073M / 1231M INFO   Simplification           (parallel_processing.hpp   : 170)   Self conjugate edge remover triggered 0 times
#   0:33:07.751  1073M / 1231M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Initial tip clipper
#   0:33:09.703  1072M / 1243M INFO   Simplification           (parallel_processing.hpp   : 170)   Initial tip clipper triggered 77085 times
#   0:33:09.707  1072M / 1243M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Initial ec remover
#   0:33:19.344  1148M / 1414M INFO   Simplification           (parallel_processing.hpp   : 170)   Initial ec remover triggered 671505 times
#   0:33:19.383  1148M / 1414M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Initial isolated edge remover
#   0:33:21.898  1086M / 1442M INFO   Simplification           (parallel_processing.hpp   : 170)   Initial isolated edge remover triggered 845410 times
#   0:33:21.921   979M / 1442M INFO   StageManager             (stage.cpp                 : 185)   STAGE == Simplification (id: simplification)
#   0:33:21.922   979M / 1442M INFO    General                 (simplification.cpp        : 368)   Graph simplification started
#   0:33:21.923   979M / 1442M INFO    General                 (graph_simplification.hpp  : 634)   Creating parallel br instance
#   0:33:21.923   979M / 1442M INFO    General                 (simplification.cpp        : 373)   PROCEDURE == Simplification cycle, iteration 1
#   0:33:21.924   979M / 1442M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Tip clipper
#   0:33:22.958   975M / 1443M INFO   Simplification           (parallel_processing.hpp   : 170)   Tip clipper triggered 69281 times
#   0:33:22.966   975M / 1443M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Bulge remover
#   0:33:55.192   970M / 1592M INFO   Simplification           (parallel_processing.hpp   : 170)   Bulge remover triggered 499842 times
#   0:33:55.221   970M / 1592M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Low coverage edge remover
#   0:33:55.687   978M / 1594M INFO   Simplification           (parallel_processing.hpp   : 170)   Low coverage edge remover triggered 0 times
#   0:33:55.687   978M / 1594M INFO    General                 (simplification.cpp        : 373)   PROCEDURE == Simplification cycle, iteration 2
#   0:33:55.687   978M / 1594M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Tip clipper
#   0:33:56.555   959M / 1594M INFO   Simplification           (parallel_processing.hpp   : 170)   Tip clipper triggered 32010 times
#   0:33:56.560   959M / 1594M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Bulge remover
#   0:33:57.005   946M / 1595M INFO   Simplification           (parallel_processing.hpp   : 170)   Bulge remover triggered 1232 times
#   0:33:57.006   946M / 1595M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Low coverage edge remover
#   0:33:57.349   947M / 1595M INFO   Simplification           (parallel_processing.hpp   : 170)   Low coverage edge remover triggered 14387 times
#   0:33:57.352   947M / 1595M INFO    General                 (simplification.cpp        : 373)   PROCEDURE == Simplification cycle, iteration 3
#   0:33:57.352   947M / 1595M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Tip clipper
#   0:33:57.388   947M / 1595M INFO   Simplification           (parallel_processing.hpp   : 170)   Tip clipper triggered 1708 times
#   0:33:57.393   947M / 1595M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Bulge remover
#   0:33:58.987   949M / 1595M INFO   Simplification           (parallel_processing.hpp   : 170)   Bulge remover triggered 3728 times
#   0:33:58.988   949M / 1595M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Low coverage edge remover
#   0:34:00.389   956M / 1597M INFO   Simplification           (parallel_processing.hpp   : 170)   Low coverage edge remover triggered 90409 times
#   0:34:00.399   956M / 1597M INFO    General                 (simplification.cpp        : 373)   PROCEDURE == Simplification cycle, iteration 4
#   0:34:00.400   956M / 1597M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Tip clipper
#   0:34:00.784   951M / 1597M INFO   Simplification           (parallel_processing.hpp   : 170)   Tip clipper triggered 8270 times
#   0:34:00.785   951M / 1597M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Bulge remover
#   0:34:06.082   940M / 1598M INFO   Simplification           (parallel_processing.hpp   : 170)   Bulge remover triggered 17575 times
#   0:34:06.086   940M / 1598M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Low coverage edge remover
#   0:34:06.349   936M / 1598M INFO   Simplification           (parallel_processing.hpp   : 170)   Low coverage edge remover triggered 27 times
#   0:34:06.349   936M / 1598M INFO    General                 (simplification.cpp        : 373)   PROCEDURE == Simplification cycle, iteration 5
#   0:34:06.349   936M / 1598M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Tip clipper
#   0:34:06.417   935M / 1598M INFO   Simplification           (parallel_processing.hpp   : 170)   Tip clipper triggered 285 times
#   0:34:06.417   935M / 1598M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Bulge remover
#   0:34:06.445   933M / 1598M INFO   Simplification           (parallel_processing.hpp   : 170)   Bulge remover triggered 8 times
#   0:34:06.446   933M / 1598M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Low coverage edge remover
#   0:34:06.446   933M / 1598M INFO   Simplification           (parallel_processing.hpp   : 170)   Low coverage edge remover triggered 0 times
#   0:34:06.447   933M / 1598M INFO    General                 (simplification.cpp        : 373)   PROCEDURE == Simplification cycle, iteration 6
#   0:34:06.449   933M / 1598M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Tip clipper
#   0:34:06.455   933M / 1598M INFO   Simplification           (parallel_processing.hpp   : 170)   Tip clipper triggered 0 times
#   0:34:06.457   933M / 1598M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Bulge remover
#   0:34:06.458   933M / 1598M INFO   Simplification           (parallel_processing.hpp   : 170)   Bulge remover triggered 0 times
#   0:34:06.461   933M / 1598M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Low coverage edge remover
#   0:34:06.466   933M / 1598M INFO   Simplification           (parallel_processing.hpp   : 170)   Low coverage edge remover triggered 0 times
#   0:34:06.605   929M / 1598M INFO   StageManager             (stage.cpp                 : 185)   STAGE == Simplification Cleanup (id: simplification_cleanup)
#   0:34:06.607   929M / 1598M INFO    General                 (simplification.cpp        : 176)   PROCEDURE == Post simplification
#   0:34:06.609   929M / 1598M INFO    General                 (graph_simplification.hpp  : 634)   Creating parallel br instance
#   0:34:06.616   929M / 1598M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Relative coverage component remover
#   0:34:09.810   928M / 1598M INFO   Simplification           (parallel_processing.hpp   : 170)   Relative coverage component remover triggered 8119 times
#   0:34:09.813   928M / 1598M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Disconnecting edges with relatively low coverage
#   0:34:10.754   928M / 1598M INFO   Simplification           (parallel_processing.hpp   : 170)   Disconnecting edges with relatively low coverage triggered 1759 times
#   0:34:10.754   928M / 1598M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Complex tip clipper
#   0:34:11.170   928M / 1598M INFO   Simplification           (parallel_processing.hpp   : 170)   Complex tip clipper triggered 903 times
#   0:34:11.171   928M / 1598M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Complex bulge remover
#   0:34:13.040   928M / 1598M INFO   Simplification           (parallel_processing.hpp   : 170)   Complex bulge remover triggered 1356 times
#   0:34:13.041   928M / 1598M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Tip clipper
#   0:34:13.355   928M / 1598M INFO   Simplification           (parallel_processing.hpp   : 170)   Tip clipper triggered 1393 times
#   0:34:13.355   928M / 1598M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Final tip clipper
#   0:34:13.609   928M / 1598M INFO   Simplification           (parallel_processing.hpp   : 170)   Final tip clipper triggered 143 times
#   0:34:13.610   928M / 1598M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Bulge remover
#   0:34:15.539   931M / 1600M INFO   Simplification           (parallel_processing.hpp   : 170)   Bulge remover triggered 858 times
#   0:34:15.539   931M / 1600M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Thorn remover (meta)
#   0:34:17.815   931M / 1600M INFO   Simplification           (parallel_processing.hpp   : 170)   Thorn remover (meta) triggered 81 times
#   0:34:17.816   931M / 1600M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Relative coverage component remover
#   0:34:20.515   931M / 1600M INFO   Simplification           (parallel_processing.hpp   : 170)   Relative coverage component remover triggered 198 times
#   0:34:20.515   931M / 1600M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Disconnecting edges with relatively low coverage
#   0:34:21.453   931M / 1600M INFO   Simplification           (parallel_processing.hpp   : 170)   Disconnecting edges with relatively low coverage triggered 82 times
#   0:34:21.454   931M / 1600M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Complex tip clipper
#   0:34:21.844   931M / 1600M INFO   Simplification           (parallel_processing.hpp   : 170)   Complex tip clipper triggered 17 times
#   0:34:21.845   931M / 1600M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Complex bulge remover
#   0:34:23.568   931M / 1600M INFO   Simplification           (parallel_processing.hpp   : 170)   Complex bulge remover triggered 32 times
#   0:34:23.568   931M / 1600M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Tip clipper
#   0:34:23.867   930M / 1600M INFO   Simplification           (parallel_processing.hpp   : 170)   Tip clipper triggered 83 times
#   0:34:23.868   930M / 1600M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Final tip clipper
#   0:34:24.140   930M / 1600M INFO   Simplification           (parallel_processing.hpp   : 170)   Final tip clipper triggered 3 times
#   0:34:24.143   930M / 1600M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Bulge remover
#   0:34:25.786   930M / 1600M INFO   Simplification           (parallel_processing.hpp   : 170)   Bulge remover triggered 39 times
#   0:34:25.787   930M / 1600M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Thorn remover (meta)
#   0:34:27.945   930M / 1600M INFO   Simplification           (parallel_processing.hpp   : 170)   Thorn remover (meta) triggered 1 times
#   0:34:27.945   930M / 1600M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Relative coverage component remover
#   0:34:30.525   930M / 1600M INFO   Simplification           (parallel_processing.hpp   : 170)   Relative coverage component remover triggered 14 times
#   0:34:30.526   930M / 1600M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Disconnecting edges with relatively low coverage
#   0:34:30.532   930M / 1600M INFO   Simplification           (parallel_processing.hpp   : 170)   Disconnecting edges with relatively low coverage triggered 2 times
#   0:34:30.542   930M / 1600M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Complex tip clipper
#   0:34:30.966   930M / 1600M INFO   Simplification           (parallel_processing.hpp   : 170)   Complex tip clipper triggered 2 times
#   0:34:30.966   930M / 1600M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Complex bulge remover
#   0:34:32.608   930M / 1600M INFO   Simplification           (parallel_processing.hpp   : 170)   Complex bulge remover triggered 0 times
#   0:34:32.608   930M / 1600M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Tip clipper
#   0:34:32.608   930M / 1600M INFO   Simplification           (parallel_processing.hpp   : 170)   Tip clipper triggered 3 times
#   0:34:32.608   930M / 1600M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Final tip clipper
#   0:34:32.609   930M / 1600M INFO   Simplification           (parallel_processing.hpp   : 170)   Final tip clipper triggered 0 times
#   0:34:32.609   930M / 1600M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Bulge remover
#   0:34:32.609   930M / 1600M INFO   Simplification           (parallel_processing.hpp   : 170)   Bulge remover triggered 1 times
#   0:34:32.609   930M / 1600M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Thorn remover (meta)
#   0:34:32.610   930M / 1600M INFO   Simplification           (parallel_processing.hpp   : 170)   Thorn remover (meta) triggered 0 times
#   0:34:32.610   930M / 1600M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Relative coverage component remover
#   0:34:35.301   930M / 1600M INFO   Simplification           (parallel_processing.hpp   : 170)   Relative coverage component remover triggered 0 times
#   0:34:35.302   930M / 1600M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Disconnecting edges with relatively low coverage
#   0:34:35.302   930M / 1600M INFO   Simplification           (parallel_processing.hpp   : 170)   Disconnecting edges with relatively low coverage triggered 0 times
#   0:34:35.302   930M / 1600M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Complex tip clipper
#   0:34:35.673   930M / 1600M INFO   Simplification           (parallel_processing.hpp   : 170)   Complex tip clipper triggered 0 times
#   0:34:35.673   930M / 1600M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Complex bulge remover
#   0:34:37.235   930M / 1600M INFO   Simplification           (parallel_processing.hpp   : 170)   Complex bulge remover triggered 0 times
#   0:34:37.236   930M / 1600M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Tip clipper
#   0:34:37.242   930M / 1600M INFO   Simplification           (parallel_processing.hpp   : 170)   Tip clipper triggered 0 times
#   0:34:37.243   930M / 1600M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Final tip clipper
#   0:34:37.243   930M / 1600M INFO   Simplification           (parallel_processing.hpp   : 170)   Final tip clipper triggered 0 times
#   0:34:37.244   930M / 1600M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Bulge remover
#   0:34:37.244   930M / 1600M INFO   Simplification           (parallel_processing.hpp   : 170)   Bulge remover triggered 0 times
#   0:34:37.244   930M / 1600M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Thorn remover (meta)
#   0:34:37.244   930M / 1600M INFO   Simplification           (parallel_processing.hpp   : 170)   Thorn remover (meta) triggered 0 times
#   0:34:37.245   930M / 1600M INFO    General                 (simplification.cpp        : 323)   Running Hidden EC remover (meta)
#   0:34:37.524   930M / 1600M INFO    General                 (simplification.cpp        : 327)   Disrupting self-conjugate edges
#   0:34:38.210   930M / 1602M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Removing isolated edges
#   0:34:38.559   928M / 1602M INFO   Simplification           (parallel_processing.hpp   : 170)   Removing isolated edges triggered 37365 times
#   0:34:38.563   925M / 1602M INFO    General                 (simplification.cpp        : 491)   Counting average coverage
#   0:34:38.833   925M / 1602M INFO    General                 (simplification.cpp        : 497)   Average coverage = 2.79281
#   0:34:38.837   925M / 1602M INFO   StageManager             (stage.cpp                 : 185)   STAGE == Contig Output (id: contig_output)
#   0:34:38.885   925M / 1602M INFO    General                 (read_converter.cpp        : 102)   Outputting contigs to /Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/K21/simplified_contigs
#   0:34:38.900   928M / 1602M INFO    General                 (binary_converter.cpp      :  96)   16384 reads processed
#   0:34:38.910   928M / 1602M INFO    General                 (binary_converter.cpp      :  96)   32768 reads processed
#   0:34:38.921   928M / 1602M INFO    General                 (binary_converter.cpp      :  96)   65536 reads processed
#   0:34:38.975   928M / 1602M INFO    General                 (binary_converter.cpp      :  96)   131072 reads processed
#   0:34:39.060   928M / 1602M INFO    General                 (binary_converter.cpp      :  96)   262144 reads processed
#   0:34:39.286   928M / 1602M INFO    General                 (binary_converter.cpp      : 111)   463976 reads written
#   0:34:39.449   925M / 1602M INFO    General                 (pipeline.cpp              : 287)   SPAdes finished
#   0:34:40.157     1M / 720M  INFO    General                 (main.cpp                  : 136)   Assembling time: 0 hours 34 minutes 40 seconds
#
# ===== K21 finished.
#
#
# ===== K33 started.
#
#
# == Running: /Users/ashley/miniconda3/envs/metagenome/bin/spades-core /Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/K33/configs/config.info /Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/K33/configs/mda_mode.info /Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/K33/configs/meta_mode.info
#
#   0:00:00.000     1M / 6M    INFO    General                 (main.cpp                  :  99)   Loaded config from /Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/K33/configs/config.info
#   0:00:00.000     1M / 6M    INFO    General                 (main.cpp                  :  99)   Loaded config from /Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/K33/configs/mda_mode.info
#   0:00:00.000     1M / 6M    INFO    General                 (main.cpp                  :  99)   Loaded config from /Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/K33/configs/meta_mode.info
#   0:00:00.000     1M / 6M    INFO    General                 (memory_limit.cpp          :  48)   Memory limit set to 250 Gb
#   0:00:00.000     1M / 6M    INFO    General                 (main.cpp                  : 107)   Starting SPAdes, built from refs/heads/master, git revision 54bed604152fd271b68bdf7b78bfd0788ea9e431
#   0:00:00.000     1M / 6M    INFO    General                 (main.cpp                  : 108)   Maximum k-mer length: 128
#   0:00:00.000     1M / 6M    INFO    General                 (main.cpp                  : 109)   Assembling dataset (/Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/dataset.info) with K=33
#   0:00:00.000     1M / 6M    INFO    General                 (main.cpp                  : 110)   Maximum # of threads to use (adjusted due to OMP capabilities): 4
#   0:00:00.000     1M / 6M    INFO    General                 (pipeline.cpp              : 212)   SPAdes started
#   0:00:00.000     1M / 6M    INFO    General                 (pipeline.cpp              : 225)   Starting from stage: read_conversion
#   0:00:00.000     1M / 6M    INFO    General                 (pipeline.cpp              : 231)   Two-step repeat resolution disabled
#   0:00:00.000     1M / 6M    INFO   GraphCore                (graph_core.hpp            : 672)   Graph created, vertex min_id: 3, edge min_id: 3
#   0:00:00.000     1M / 6M    INFO   GraphCore                (graph_core.hpp            : 673)   Vertex size: 48, edge size: 40
#   0:00:00.000     1M / 6M    INFO    General                 (edge_index.hpp            : 115)   Size of edge index entries: 12/8
#   0:00:00.000     1M / 7M    INFO   StageManager             (stage.cpp                 : 185)   STAGE == Binary Read Conversion (id: read_conversion)
#   0:00:00.009     1M / 7M    INFO    General                 (read_converter.cpp        :  53)   Binary reads detected
#   0:00:00.021     1M / 7M    INFO   StageManager             (stage.cpp                 : 185)   STAGE == de Bruijn graph construction (id: construction)
#   0:00:00.033     1M / 7M    INFO    General                 (construction.cpp          : 118)   Contigs from previous K will be used: /Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/K21/simplified_contigs
#   0:00:00.068     1M / 7M    INFO    General                 (construction.cpp          : 153)   Max read length 300
#   0:00:00.069     1M / 7M    INFO    General                 (construction.cpp          : 159)   Average read length 183.73
#   0:00:00.070     1M / 7M    INFO    General                 (stage.cpp                 : 117)   PROCEDURE == k+1-mer counting (id: construction:kpomer_counting)
#   0:00:00.072     1M / 7M    INFO    General                 (kmer_index_builder.hpp    : 243)   Splitting kmer instances into 40 files using 4 threads. This might take a while.
#   0:00:00.076     1M / 7M    INFO    General                 (file_limit.hpp            :  32)   Open file limit set to 4096
#   0:00:00.080     1M / 7M    INFO    General                 (kmer_splitter.hpp         :  93)   Memory available for splitting buffers: 20.8333 Gb
#   0:00:00.081     1M / 7M    INFO    General                 (kmer_splitter.hpp         : 101)   Using cell size of 838860
#   0:01:12.113  2401M / 2401M INFO    General                 (kmer_splitters.hpp        : 125)   Processed 1778639 reads
#   0:01:47.830  2401M / 2401M INFO    General                 (kmer_splitters.hpp        : 125)   Processed 3560050 reads
#   0:02:16.380  2401M / 2401M INFO    General                 (kmer_splitters.hpp        : 125)   Processed 5336014 reads
#   0:02:47.776  2401M / 2401M INFO    General                 (kmer_splitters.hpp        : 125)   Processed 7107339 reads
#   0:03:22.839  2401M / 2401M INFO    General                 (kmer_splitters.hpp        : 125)   Processed 8750384 reads
#   0:03:43.650  2401M / 2401M INFO    General                 (kmer_splitters.hpp        : 125)   Processed 9186776 reads
#   0:03:43.650     1M / 388M  INFO    General                 (kmer_splitters.hpp        : 131)   Used 9186776 reads
#   0:03:43.920     1M / 388M  INFO    General                 (kmer_index_builder.hpp    : 249)   Starting k-mer counting.
#   0:08:49.355     1M / 401M  INFO    General                 (kmer_index_builder.hpp    : 260)   K-mer counting done. There are 336428575 kmers in total.
#   0:08:49.355     1M / 401M  INFO    General                 (stage.cpp                 : 117)   PROCEDURE == Extension index construction (id: construction:extension_index_construction)
#   0:08:49.386     1M / 401M  INFO   K-mer Index Building     (kmer_index_builder.hpp    : 438)   Building kmer index
#   0:08:49.386     1M / 401M  INFO    General                 (kmer_index_builder.hpp    : 243)   Splitting kmer instances into 40 files using 4 threads. This might take a while.
#   0:08:49.387     1M / 401M  INFO    General                 (file_limit.hpp            :  32)   Open file limit set to 4096
#   0:08:49.393     1M / 401M  INFO    General                 (kmer_splitter.hpp         :  93)   Memory available for splitting buffers: 20.8333 Gb
#   0:08:49.395     1M / 401M  INFO    General                 (kmer_splitter.hpp         : 101)   Using cell size of 838860
#   0:08:57.049  2401M / 2401M INFO    General                 (kmer_splitters.hpp        : 194)   Processed 8782600 kmers
#   0:09:07.481  2401M / 2401M INFO    General                 (kmer_splitters.hpp        : 194)   Processed 18266695 kmers
#   0:09:19.881  2401M / 2401M INFO    General                 (kmer_splitters.hpp        : 194)   Processed 29360593 kmers
#   0:09:37.583  2401M / 2401M INFO    General                 (kmer_splitters.hpp        : 194)   Processed 41929678 kmers
#   0:09:47.967  2401M / 2401M INFO    General                 (kmer_splitters.hpp        : 194)   Processed 51388299 kmers
#   0:10:04.695  2401M / 2401M INFO    General                 (kmer_splitters.hpp        : 194)   Processed 62247515 kmers
#   0:10:21.145  2401M / 2401M INFO    General                 (kmer_splitters.hpp        : 194)   Processed 75492953 kmers
#   0:10:34.951  2401M / 2401M INFO    General                 (kmer_splitters.hpp        : 194)   Processed 84941408 kmers
#   0:10:48.208  2401M / 2401M INFO    General                 (kmer_splitters.hpp        : 194)   Processed 95746255 kmers
#   0:11:03.478  2401M / 2401M INFO    General                 (kmer_splitters.hpp        : 194)   Processed 109121419 kmers
#   0:11:14.469  2401M / 2401M INFO    General                 (kmer_splitters.hpp        : 194)   Processed 118573373 kmers
#   0:11:27.715  2401M / 2401M INFO    General                 (kmer_splitters.hpp        : 194)   Processed 129381852 kmers
#   0:11:44.231  2401M / 2401M INFO    General                 (kmer_splitters.hpp        : 194)   Processed 142757170 kmers
#   0:11:56.173  2401M / 2401M INFO    General                 (kmer_splitters.hpp        : 194)   Processed 152201596 kmers
#   0:12:11.047  2401M / 2401M INFO    General                 (kmer_splitters.hpp        : 194)   Processed 163011653 kmers
#   0:12:27.253  2401M / 2401M INFO    General                 (kmer_splitters.hpp        : 194)   Processed 176382302 kmers
#   0:12:38.959  2401M / 2401M INFO    General                 (kmer_splitters.hpp        : 194)   Processed 185828281 kmers
#   0:12:51.208  2401M / 2401M INFO    General                 (kmer_splitters.hpp        : 194)   Processed 196633455 kmers
#   0:14:28.799  2401M / 2401M INFO    General                 (kmer_splitters.hpp        : 194)   Processed 277312265 kmers
#   0:15:47.853  2401M / 2401M INFO    General                 (kmer_splitters.hpp        : 199)   Used 336429235 kmers.
#   0:15:47.853     1M / 120M  INFO    General                 (kmer_index_builder.hpp    : 249)   Starting k-mer counting.
#   0:22:34.962     1M / 147M  INFO    General                 (kmer_index_builder.hpp    : 260)   K-mer counting done. There are 337049792 kmers in total.
#   0:22:34.963     1M / 147M  INFO   K-mer Index Building     (kmer_index_builder.hpp    : 395)   Building perfect hash indices
#   0:26:06.108   253M / 418M  INFO   K-mer Index Building     (kmer_index_builder.hpp    : 431)   Index built. Total 337049792 kmers, 243467616 bytes occupied (5.77879 bits per kmer).
#   0:26:06.108   253M / 418M  INFO    General                 (kmer_index_builder.hpp    : 169)   Merging final buckets.
#   0:29:21.115   578M / 740M  INFO   DeBruijnExtensionIndexBu (kmer_extension_index_build: 100)   Building k-mer extensions from k+1-mers
#   0:32:28.829   578M / 578M  INFO   DeBruijnExtensionIndexBu (kmer_extension_index_build: 105)   Building k-mer extensions from k+1-mers finished.
#   0:32:28.830   578M / 578M  INFO    General                 (stage.cpp                 : 117)   PROCEDURE == Early tip clipping (id: construction:early_tip_clipper)
#   0:32:28.830   578M / 578M  INFO    General                 (construction.cpp          : 301)   Early tip clipper length bound set as (RL - K)
#   0:32:28.830   578M / 578M  INFO   Early tip clipping       (early_simplification.hpp  :  47)   Early tip clipping
#   0:38:00.478   658M / 658M  INFO   Early tip clipping       (early_simplification.hpp  :  82)   #tipped junctions: 973180
#   0:38:01.296   658M / 698M  INFO   Early tip clipping       (early_simplification.hpp  :  93)   Clipped tips: 977155
#   0:38:01.317   578M / 626M  INFO   Early tip clipping       (early_simplification.hpp  :  49)   37121659 34-mers were removed by early tip clipper
#   0:38:01.317   578M / 626M  INFO    General                 (stage.cpp                 : 117)   PROCEDURE == Condensing graph (id: construction:graph_condensing)
#   0:38:04.454   578M / 626M  INFO   UnbranchingPathExtractor (debruijn_graph_constructor: 354)   Extracting unbranching paths
#   0:45:25.294   790M / 1289M INFO   UnbranchingPathExtractor (debruijn_graph_constructor: 373)   Extracting unbranching paths finished. 3552323 sequences extracted
#   0:46:42.532   790M / 879M  INFO   UnbranchingPathExtractor (debruijn_graph_constructor: 309)   Collecting perfect loops
#   0:50:55.607   854M / 1122M INFO   UnbranchingPathExtractor (debruijn_graph_constructor: 342)   Collecting perfect loops finished. 6188 loops collected
#   0:50:56.634   790M / 841M  INFO    General                 (debruijn_graph_constructor: 487)   Total 7117022 edges to create
#   0:50:56.636  1067M / 1067M INFO    General                 (debruijn_graph_constructor: 489)   Collecting link records
#   0:51:13.601  1180M / 1212M INFO    General                 (debruijn_graph_constructor: 491)   Ordering link records
#   0:51:14.432  1180M / 1212M INFO    General                 (debruijn_graph_constructor: 493)   Sorting done
#   0:51:14.634  1212M / 1242M INFO    General                 (debruijn_graph_constructor: 503)   Total 4179728 vertices to create
#   0:51:14.640  1601M / 1601M INFO    General                 (debruijn_graph_constructor: 506)   Connecting the graph
#   0:51:43.932  1401M / 1507M INFO    General                 (stage.cpp                 : 117)   PROCEDURE == Filling coverage indices (PHM) (id: construction:coverage_filling_phm)
#   0:51:43.932  1401M / 1508M INFO   K-mer Index Building     (kmer_index_builder.hpp    : 395)   Building perfect hash indices
#   0:54:41.585  1654M / 1654M INFO   K-mer Index Building     (kmer_index_builder.hpp    : 431)   Index built. Total 336428575 kmers, 243019064 bytes occupied (5.7788 bits per kmer).
#   0:54:43.267  2938M / 2938M INFO    General                 (coverage_hash_map_builder.:  47)   Collecting k-mer coverage information from reads, this takes a while.
#   0:56:55.056  2938M / 2938M INFO    General                 (construction.cpp          : 430)   Filling coverage and flanking coverage from PHM
#   0:58:17.760  2938M / 2938M INFO    General                 (coverage_filling.hpp      :  82)   Processed 4000000 edges
#   0:59:20.221  2938M / 2938M INFO    General                 (coverage_filling.hpp      :  82)   Processed 7115849 edges
#   0:59:21.488   824M / 824M  INFO   StageManager             (stage.cpp                 : 185)   STAGE == Raw Simplification (id: raw_simplification)
#   0:59:21.504   824M / 824M  INFO    General                 (simplification.cpp        : 127)   PROCEDURE == Initial cleaning
#   0:59:21.509   824M / 824M  INFO    General                 (graph_simplification.hpp  : 662)   Flanking coverage based disconnection disabled
#   0:59:21.509   824M / 824M  INFO   Simplification           (parallel_processing.hpp   : 167)   Running Self conjugate edge remover
#   0:59:22.440   824M / 986M  INFO   Simplification           (parallel_processing.hpp   : 170)   Self conjugate edge remover triggered 162 times
#   0:59:22.440   824M / 986M  INFO   Simplification           (parallel_processing.hpp   : 167)   Running Initial tip clipper
#   0:59:27.289   823M / 999M  INFO   Simplification           (parallel_processing.hpp   : 170)   Initial tip clipper triggered 75315 times
#   0:59:27.295   823M / 999M  INFO   Simplification           (parallel_processing.hpp   : 167)   Running Initial ec remover
#   0:59:37.398   856M / 1092M INFO   Simplification           (parallel_processing.hpp   : 170)   Initial ec remover triggered 365375 times
#   0:59:37.455   856M / 1092M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Initial isolated edge remover
#   0:59:42.505   795M / 1157M INFO   Simplification           (parallel_processing.hpp   : 170)   Initial isolated edge remover triggered 1075322 times
# ...
#   1:51:28.042  2435M / 2435M INFO    General                 (distance_estimation.cpp   : 104)   Filling scaffolding index
#   1:51:28.044  2435M / 2435M INFO   DistanceEstimator        (distance_estimation.hpp   : 116)   Using SMOOTHING distance estimator
#   1:51:54.706  2435M / 2435M INFO    General                 (distance_estimation.cpp   :  37)   Filtering info
#   1:51:54.707  2435M / 2435M INFO    General                 (pair_info_filters.hpp     : 242)   Start filtering; library index size: 406685
#   1:51:55.396  2443M / 2443M INFO    General                 (pair_info_filters.hpp     : 263)   Done filtering; library index size: 406685
#   1:51:55.417  2435M / 2435M INFO    General                 (distance_estimation.cpp   : 186)   Clearing raw paired index
#   1:51:55.556  2407M / 2407M INFO   StageManager             (stage.cpp                 : 185)   STAGE == Repeat Resolving (id: repeat_resolving)
#   1:51:55.582  2407M / 2407M INFO    General                 (repeat_resolving.cpp      :  87)   Using Path-Extend repeat resolving
#   1:51:55.594  2407M / 2407M INFO    General                 (launcher.cpp              : 600)   ExSPAnder repeat resolving tool started
#   1:52:09.691  7070M / 7070M INFO    General                 (launcher.cpp              : 418)   Creating main extenders, unique edge length = 2000
#   1:52:09.803  7110M / 7110M INFO    General                 (launcher.cpp              : 342)   filling path container
#   1:52:10.335  7186M / 7186M INFO    General                 (extenders_logic.cpp       : 345)   Creating extender; library index size: 245810
#   1:52:10.342  7206M / 7206M INFO    General                 (extenders_logic.cpp       : 345)   Creating extender; library index size: 245810
#   1:52:12.326  7258M / 7258M INFO    General                 (extenders_logic.cpp       :  47)   resolvable_repeat_length_bound set to 10000
#   1:52:12.722  7296M / 7296M INFO    General                 (extenders_logic.cpp       : 543)   Using 1 paired-end library
#   1:52:12.728  7296M / 7296M INFO    General                 (extenders_logic.cpp       : 544)   Using 1 paired-end scaffolding library
#   1:52:12.747  7296M / 7296M INFO    General                 (extenders_logic.cpp       : 545)   Using 1 single read library
#   1:52:12.980  7296M / 7296M INFO    General                 (launcher.cpp              : 385)   Filling backbone edges for long reads scaffolding...
#   1:52:12.984  7296M / 7296M INFO    General                 (launcher.cpp              : 387)    with long reads paths
#   1:52:12.989  7296M / 7296M INFO    General                 (launcher.cpp              : 396)   Removing fake unique with paired-end libs
#   1:52:12.996  7296M / 7296M INFO    General                 (launcher.cpp              : 407)   0 unique edges
#   1:52:13.002  7296M / 7296M INFO    General                 (extenders_logic.cpp       : 446)   Using 0 long reads scaffolding libraries
#   1:52:13.010  7296M / 7296M INFO    General                 (extenders_logic.cpp       : 456)   Using additional coordinated coverage extender
#   1:52:13.022  7316M / 7316M INFO    General                 (launcher.cpp              : 447)   Total number of extenders is 5
#   1:52:13.035  7316M / 7316M INFO    General                 (path_extenders.cpp        :  36)   Processed 0 paths from 194008 (0%)
#   1:52:13.110  7320M / 7320M INFO    General                 (path_extenders.cpp        :  34)   Processed 128 paths from 194008 (0%)
#   1:52:13.134  7323M / 7323M INFO    General                 (path_extenders.cpp        :  34)   Processed 256 paths from 194008 (0%)
#   1:52:13.185  7330M / 7330M INFO    General                 (path_extenders.cpp        :  34)   Processed 512 paths from 194008 (0%)
#   1:52:13.283  7342M / 7342M INFO    General                 (path_extenders.cpp        :  34)   Processed 1024 paths from 194008 (0%)
#   1:52:13.421  7367M / 7367M INFO    General                 (path_extenders.cpp        :  34)   Processed 2048 paths from 194008 (1%)
#   1:52:13.682  7417M / 7417M INFO    General                 (path_extenders.cpp        :  34)   Processed 4096 paths from 194008 (2%)
#   1:52:14.023  7516M / 7516M INFO    General                 (path_extenders.cpp        :  34)   Processed 8192 paths from 194008 (4%)
#   1:52:14.722  7714M / 7714M INFO    General                 (path_extenders.cpp        :  34)   Processed 16384 paths from 194008 (8%)
#   1:52:14.971  7787M / 7787M INFO    General                 (path_extenders.cpp        :  36)   Processed 19401 paths from 194008 (10%)
#   1:52:16.035  8109M / 8109M INFO    General                 (path_extenders.cpp        :  34)   Processed 32768 paths from 194008 (16%)
#   1:52:16.570  8254M / 8254M INFO    General                 (path_extenders.cpp        :  36)   Processed 38802 paths from 194008 (20%)
#   1:52:17.957  8719M / 8719M INFO    General                 (path_extenders.cpp        :  36)   Processed 58203 paths from 194008 (30%)
#   1:52:19.020  8895M / 8895M INFO    General                 (path_extenders.cpp        :  34)   Processed 65536 paths from 194008 (33%)
#   1:52:19.896  9185M / 9185M INFO    General                 (path_extenders.cpp        :  36)   Processed 77604 paths from 194008 (40%)
#   1:52:21.157  9649M / 9649M INFO    General                 (path_extenders.cpp        :  36)   Processed 97005 paths from 194008 (50%)
#   1:52:22.742    10G / 10G   INFO    General                 (path_extenders.cpp        :  36)   Processed 116406 paths from 194008 (60%)
#   1:52:24.056    11G / 11G   INFO    General                 (path_extenders.cpp        :  34)   Processed 131072 paths from 194008 (67%)
#   1:52:24.524    11G / 11G   INFO    General                 (path_extenders.cpp        :  36)   Processed 135807 paths from 194008 (70%)
#   1:52:26.026    11G / 11G   INFO    General                 (path_extenders.cpp        :  36)   Processed 155208 paths from 194008 (80%)
#   1:52:27.538    12G / 12G   INFO    General                 (path_extenders.cpp        :  36)   Processed 174609 paths from 194008 (90%)
#   1:52:31.038    12G / 12G   INFO    General                 (launcher.cpp              : 250)   Finalizing paths
#   1:52:31.047    12G / 12G   INFO    General                 (launcher.cpp              : 252)   Deduplicating paths
#   1:52:33.859    12G / 12G   INFO    General                 (launcher.cpp              : 256)   Paths deduplicated
#   1:52:33.872    12G / 12G   INFO   PEResolver               (pe_resolver.cpp           :  60)   Removing overlaps
#   1:52:33.880    12G / 12G   INFO   PEResolver               (pe_resolver.cpp           :  70)   Marking overlaps
#   1:52:33.889    12G / 12G   INFO   OverlapRemover           (overlap_remover.hpp       : 116)   Marking start/end overlaps
#   1:52:36.937    12G / 12G   INFO   OverlapRemover           (overlap_remover.hpp       : 119)   Marking remaining overlaps
#   1:52:39.736    12G / 12G   INFO   PEResolver               (pe_resolver.cpp           :  73)   Splitting paths
#   1:52:40.172    12G / 12G   INFO   PEResolver               (pe_resolver.cpp           :  78)   Deduplicating paths
#   1:52:40.433    12G / 12G   INFO   PEResolver               (pe_resolver.cpp           :  80)   Overlaps removed
#   1:52:46.918    12G / 12G   INFO    General                 (launcher.cpp              : 273)   Paths finalized
#   1:52:46.982    12G / 12G   INFO    General                 (launcher.cpp              : 454)   Closing gaps in paths
#   1:52:59.679    17G / 17G   INFO    General                 (launcher.cpp              : 484)   Gap closing completed
#   1:53:01.495    17G / 17G   INFO    General                 (launcher.cpp              : 302)   Traversing tandem repeats
#   1:53:07.828    17G / 17G   INFO    General                 (launcher.cpp              : 312)   Traversed 32 loops
#   1:53:07.920    17G / 17G   INFO    General                 (launcher.cpp              : 250)   Finalizing paths
#   1:53:07.932    17G / 17G   INFO    General                 (launcher.cpp              : 252)   Deduplicating paths
#   1:53:08.355    17G / 17G   INFO    General                 (launcher.cpp              : 256)   Paths deduplicated
#   1:53:08.378    17G / 17G   INFO   PEResolver               (pe_resolver.cpp           :  60)   Removing overlaps
#   1:53:08.413    17G / 17G   INFO   PEResolver               (pe_resolver.cpp           :  70)   Marking overlaps
#   1:53:08.424    17G / 17G   INFO   OverlapRemover           (overlap_remover.hpp       : 116)   Marking start/end overlaps
#   1:53:12.696    17G / 17G   INFO   OverlapRemover           (overlap_remover.hpp       : 119)   Marking remaining overlaps
#   1:53:16.185    17G / 17G   INFO   PEResolver               (pe_resolver.cpp           :  73)   Splitting paths
#   1:53:16.322    17G / 17G   INFO   PEResolver               (pe_resolver.cpp           :  78)   Deduplicating paths
#   1:53:16.515    17G / 17G   INFO   PEResolver               (pe_resolver.cpp           :  80)   Overlaps removed
#   1:53:21.484    17G / 17G   INFO    General                 (launcher.cpp              : 273)   Paths finalized
#   1:53:21.569    17G / 17G   INFO    General                 (launcher.cpp              : 664)   ExSPAnder repeat resolving tool finished
#   1:53:40.459  7162M / 7162M INFO   StageManager             (stage.cpp                 : 185)   STAGE == Contig Output (id: contig_output)
#   1:53:40.889  7162M / 7162M INFO    General                 (contig_output.hpp         :  16)   Outputting contigs to /Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/K55/before_rr.fasta
#   1:53:46.024  7162M / 7162M INFO    General                 (contig_output_stage.cpp   : 151)   Writing GFA graph to /Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/K55/assembly_graph_with_scaffolds.gfa
#   1:53:47.919  7162M / 7162M INFO    General                 (contig_output_stage.cpp   : 165)   Outputting FastG graph to /Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/K55/assembly_graph.fastg
#   1:53:50.799  7162M / 7162M INFO    General                 (contig_output_stage.cpp   : 196)   Breaking scaffolds
#   1:54:10.522    12G / 12G   INFO    General                 (contig_output_stage.cpp   :  98)   Outputting contigs to /Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/K55/final_contigs.fasta
#   1:54:12.319    12G / 12G   INFO    General                 (contig_output_stage.cpp   : 104)   Outputting FastG paths to /Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/K55/final_contigs.paths
#   1:54:30.640  7289M / 7289M INFO    General                 (contig_output_stage.cpp   :  98)   Outputting contigs to /Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/K55/scaffolds.fasta
#   1:54:32.352  7289M / 7289M INFO    General                 (contig_output_stage.cpp   : 104)   Outputting FastG paths to /Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/K55/scaffolds.paths
#   1:54:34.801  7289M / 7289M INFO    General                 (contig_output_stage.cpp   : 111)   Populating GFA with scaffold paths
#   1:54:35.886  7162M / 7162M INFO    General                 (pipeline.cpp              : 287)   SPAdes finished
#   1:54:55.489     1M / 259M  INFO    General                 (main.cpp                  : 136)   Assembling time: 1 hours 54 minutes 55 seconds
#
# ===== K55 finished.
#
#
# ===== Copy files started.
#
#
# == Running: /Users/ashley/miniconda3/envs/metagenome/bin/python /Users/ashley/miniconda3/envs/metagenome/share/spades/spades_pipeline/scripts/copy_files.py /Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/K55/before_rr.fasta /Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/before_rr.fasta /Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/K55/assembly_graph_after_simplification.gfa /Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/assembly_graph_after_simplification.gfa /Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/K55/final_contigs.fasta /Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/contigs.fasta /Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/K55/first_pe_contigs.fasta /Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/first_pe_contigs.fasta /Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/K55/strain_graph.gfa /Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/strain_graph.gfa /Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/K55/scaffolds.fasta /Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/scaffolds.fasta /Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/K55/scaffolds.paths /Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/scaffolds.paths /Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/K55/assembly_graph_with_scaffolds.gfa /Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/assembly_graph_with_scaffolds.gfa /Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/K55/assembly_graph.fastg /Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/assembly_graph.fastg /Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/K55/final_contigs.paths /Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/contigs.paths
#
#
# ===== Copy files finished.
#
#
# ===== Assembling finished.
#
#
# ===== Breaking scaffolds started.
#
#
# == Running: /Users/ashley/miniconda3/envs/metagenome/bin/python /Users/ashley/miniconda3/envs/metagenome/share/spades/spades_pipeline/scripts/breaking_scaffolds_script.py --result_scaffolds_filename /Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/scaffolds.fasta --misc_dir /Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/misc --threshold_for_breaking_scaffolds 3
#
#
# ===== Breaking scaffolds finished.
#
#
# ===== Terminate started.
#
#
# ===== Terminate finished.
#
#  * Assembled contigs are in "/Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/contigs.fasta"
#  * Assembled scaffolds are in "/Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/scaffolds.fasta"
#  * Paths in the assembly graph corresponding to the contigs are in "/Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/contigs.paths"
#  * Paths in the assembly graph corresponding to the scaffolds are in "/Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/scaffolds.paths"
#  * Assembly graph is in "/Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/assembly_graph.fastg"
#  * Assembly graph in GFA format is in "/Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/assembly_graph_with_scaffolds.gfa"
#
# ======= SPAdes pipeline finished WITH WARNINGS!
#
# === Error correction and assembling warnings:
#  * 1:14:19.279  2485M / 2485M WARN    General                 (pair_info_count.cpp       : 377)   Estimated mean insert size 229.554 is very small compared to read length 300
#  * 1:44:43.816  2400M / 2400M WARN    General                 (pair_info_count.cpp       : 377)   Estimated mean insert size 229.672 is very small compared to read length 300
# ======= Warnings saved to /Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/warnings.log
#
# SPAdes log can be found here: /Volumes/Ashley's External Drive/metagenome-demos/SPAdes_out/ERR1424899_spades/spades.log
#
# Thank you for using SPAdes!

# %% [markdown]
# Let's navigate to the output folder and see what's there

# %%
cd ../SPAdes_out/ERR1424899_spades

# %%
ls
# Out:
# K21					misc
# K33					params.txt
# K55					pipeline_state
# assembly_graph.fastg			run_spades.sh
# assembly_graph_after_simplification.gfa	run_spades.yaml
# assembly_graph_with_scaffolds.gfa	scaffolds.fasta
# before_rr.fasta				scaffolds.paths
# contigs.fasta				spades.log
# contigs.paths				split_input
# dataset.info				strain_graph.gfa
# first_pe_contigs.fasta			tmp
# input_dataset.yaml			warnings.log
